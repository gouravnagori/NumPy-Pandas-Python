# %%
# Kaggle Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("ai_model_arena_rankings.csv.csv")
df
# Out:
#                  model_name   organization            license       rating  \
# 0                vicuna-13b          LMSYS  Llama 2 Community  1094.000000
# 1                 koala-13b    UC Berkeley     Non-commercial  1015.000000
# 2          RWKV-4-Raven-14B           RWKV         Apache 2.0   979.000000
# 3          oasst-pythia-12b  OpenAssistant         Apache 2.0   941.000000
# 4                alpaca-13b       Stanford     Non-commercial   935.000000
# ...                     ...            ...                ...          ...
# 97372          gpt-5-search         openai        Proprietary  1132.337817
# 97373    ppl-sonar-pro-high     Perplexity        Proprietary  1129.385404
# 97374  claude-opus-4-search      anthropic        Proprietary  1126.476734
# 97375      diffbot-small-xl        diffbot         Apache 2.0  1022.913853
# 97376     api-gpt-4o-search         openai        Proprietary  1006.215621
#
# ...

# %%
df.head()
# Out:
#          model_name   organization            license  rating  rating_lower  \
# 0        vicuna-13b          LMSYS  Llama 2 Community  1094.0           NaN
# 1         koala-13b    UC Berkeley     Non-commercial  1015.0           NaN
# 2  RWKV-4-Raven-14B           RWKV         Apache 2.0   979.0           NaN
# 3  oasst-pythia-12b  OpenAssistant         Apache 2.0   941.0           NaN
# 4        alpaca-13b       Stanford     Non-commercial   935.0           NaN
#
#    rating_upper  variance  vote_count  rank category leaderboard_publish_date  \
# 0           NaN       NaN         NaN   1.0  overall               2023-05-08
# 1           NaN       NaN         NaN   2.0  overall               2023-05-08
# 2           NaN       NaN         NaN   3.0  overall               2023-05-08
# 3           NaN       NaN         NaN   4.0  overall               2023-05-08
# 4           NaN       NaN         NaN   5.0  overall               2023-05-08
#
#   subset
# 0   text
# 1   text
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97377 entries, 0 to 97376
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   model_name                97377 non-null  object
#  1   organization              93900 non-null  object
#  2   license                   97246 non-null  object
#  3   rating                    97377 non-null  float64
#  4   rating_lower              97070 non-null  float64
#  5   rating_upper              97070 non-null  float64
#  6   variance                  97070 non-null  float64
#  7   vote_count                97070 non-null  float64
#  8   rank                      97377 non-null  float64
#  9   category                  97377 non-null  object
#  10  leaderboard_publish_date  97377 non-null  object
#  11  subset                    97377 non-null  object
# dtypes: float64(6), object(6)
# memory usage: 8.9+ MB

# %%
df.describe()
# Out:
#              rating  rating_lower  rating_upper      variance     vote_count  \
# count  97377.000000  97070.000000  97070.000000  97070.000000   97070.000000
# mean    1232.582439   1226.333891   1240.476336     16.858066   23586.333728
# std      145.454932    146.240327    143.613960     20.661015   27389.381794
# min      789.000000    782.043296    800.000000      0.000000      54.000000
# 25%     1125.959993   1119.161926   1135.238584      4.967224    5243.000000
# 50%     1240.190789   1234.672228   1247.290220     10.444272   12857.000000
# 75%     1348.771914   1343.719372   1356.460212     22.175828   32191.000000
# max     1664.985725   1644.632424   1685.339027    777.424034  202735.000000
#
#                rank
# count  97377.000000
# mean     119.164197
# std       89.941677
# min        1.000000
# 25%       43.000000
# 50%       99.000000
# 75%      180.000000
# max      374.000000

# %% [raw]
#                               SELECTING DATA

# %%
df["license"]
# Out:
# 0        Llama 2 Community
# 1           Non-commercial
# 2               Apache 2.0
# 3               Apache 2.0
# 4           Non-commercial
#                ...
# 97372          Proprietary
# 97373          Proprietary
# 97374          Proprietary
# 97375           Apache 2.0
# 97376          Proprietary
# Name: license, Length: 97377, dtype: object

# %%
df["model_name"]
# Out:
# 0                  vicuna-13b
# 1                   koala-13b
# 2            RWKV-4-Raven-14B
# 3            oasst-pythia-12b
# 4                  alpaca-13b
#                  ...
# 97372            gpt-5-search
# 97373      ppl-sonar-pro-high
# 97374    claude-opus-4-search
# 97375        diffbot-small-xl
# 97376       api-gpt-4o-search
# Name: model_name, Length: 97377, dtype: object

# %%
df[["model_name", "license"]]
# Out:
#                  model_name            license
# 0                vicuna-13b  Llama 2 Community
# 1                 koala-13b     Non-commercial
# 2          RWKV-4-Raven-14B         Apache 2.0
# 3          oasst-pythia-12b         Apache 2.0
# 4                alpaca-13b     Non-commercial
# ...                     ...                ...
# 97372          gpt-5-search        Proprietary
# 97373    ppl-sonar-pro-high        Proprietary
# 97374  claude-opus-4-search        Proprietary
# 97375      diffbot-small-xl         Apache 2.0
# 97376     api-gpt-4o-search        Proprietary
#
# [97377 rows x 2 columns]

# %%
# Select rows ( label & index based )
# loc and iloc
print(df.loc[0])
print(df.loc[0:3])  # in loc ending index is inclusive
print("")
print("")
print("")
print(df.iloc[0])
print(df.iloc[0:3])  # in iloc ending index is exclusive
# Out:
# model_name                         vicuna-13b
# organization                            LMSYS
# license                     Llama 2 Community
# rating                                 1094.0
# rating_lower                              NaN
# rating_upper                              NaN
# variance                                  NaN
# vote_count                                NaN
# rank                                      1.0
# category                              overall
# leaderboard_publish_date           2023-05-08
# subset                                   text
# Name: 0, dtype: object
#          model_name   organization            license  rating  rating_lower  \
# 0        vicuna-13b          LMSYS  Llama 2 Community  1094.0           NaN
# 1         koala-13b    UC Berkeley     Non-commercial  1015.0           NaN
# 2  RWKV-4-Raven-14B           RWKV         Apache 2.0   979.0           NaN
# 3  oasst-pythia-12b  OpenAssistant         Apache 2.0   941.0           NaN
#
# ...

# %%
# cells - rows , column
df.loc[0,"license"]
df.loc[0:2, ["license" , "rating" , "organization"]]

df.iloc[0:2, 0:3]
df.iloc[1, 2]
        
df.iloc[0:3, 0:4]
# Out:
#          model_name organization            license  rating
# 0        vicuna-13b        LMSYS  Llama 2 Community  1094.0
# 1         koala-13b  UC Berkeley     Non-commercial  1015.0
# 2  RWKV-4-Raven-14B         RWKV         Apache 2.0   979.0

# %%
df
# Out:
#                  model_name   organization            license       rating  \
# 0                vicuna-13b          LMSYS  Llama 2 Community  1094.000000
# 1                 koala-13b    UC Berkeley     Non-commercial  1015.000000
# 2          RWKV-4-Raven-14B           RWKV         Apache 2.0   979.000000
# 3          oasst-pythia-12b  OpenAssistant         Apache 2.0   941.000000
# 4                alpaca-13b       Stanford     Non-commercial   935.000000
# ...                     ...            ...                ...          ...
# 97372          gpt-5-search         openai        Proprietary  1132.337817
# 97373    ppl-sonar-pro-high     Perplexity        Proprietary  1129.385404
# 97374  claude-opus-4-search      anthropic        Proprietary  1126.476734
# 97375      diffbot-small-xl        diffbot         Apache 2.0  1022.913853
# 97376     api-gpt-4o-search         openai        Proprietary  1006.215621
#
# ...

# %%
df.at[97376, "organization"]
# Out:
# 'openai'

# %%
df.iat[97376, 1]

# at and iat mainly used for selecting the scalar value
# Out:
# 'openai'

# %%
df.loc[97376,"organization"]
# Out:
# 'openai'

# %% [raw]
# here view is created not copy
# and if you want to change the original data then it is good practice to use copy() method.
